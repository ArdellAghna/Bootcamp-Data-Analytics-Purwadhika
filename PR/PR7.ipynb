# %%
import pandas as pd

df = pd.read_csv('synthetic_fraud_dataset.csv')

# %%
df.head()
# Out:
#    transaction_id  user_id       amount transaction_type merchant_category  \
# 0            9608      363  4922.587542              ATM            Travel
# 1             456      692    48.018303               QR              Food
# 2            4747      587   136.881960           Online            Travel
# 3            6934      445    80.534719              POS          Clothing
# 4            1646      729   120.041158           Online           Grocery
#
#   country  hour  device_risk_score  ip_risk_score  is_fraud
# 0      TR    12           0.992347       0.947908         1
# 1      US    21           0.168571       0.224057         0
# 2      TR    14           0.296127       0.125058         0
# 3      TR    23           0.124801       0.159243         0
# 4      FR    16           0.098129       0.027542         0

# %%
df[df['is_fraud'] == 1]
# Out:
#       transaction_id  user_id       amount transaction_type merchant_category  \
# 0               9608      363  4922.587542              ATM            Travel
# 23              9933      121  4284.177967              ATM              Food
# 84              9637      560  1148.378114              POS            Travel
# 87              9711      935   952.547905               QR            Travel
# 89              9939      291  2865.421641              ATM              Food
# ...              ...      ...          ...              ...               ...
# 9787            9762      217  1455.533469               QR              Food
# 9794            9634      185  2231.990705               QR          Clothing
# 9814            9695      607    18.620488               QR            Travel
# 9856            9947      123  1381.201430              POS              Food
# 9991            9644      953  1546.529140              POS          Clothing
#
# ...

# %%
df[df['is_fraud'] == 0]
# Out:
#       transaction_id  user_id      amount transaction_type merchant_category  \
# 1                456      692   48.018303               QR              Food
# 2               4747      587  136.881960           Online            Travel
# 3               6934      445   80.534719              POS          Clothing
# 4               1646      729  120.041158           Online           Grocery
# 5               2183      944   97.108625              POS          Clothing
# ...              ...      ...         ...              ...               ...
# 9995            1076      482   58.366442              POS          Clothing
# 9996            4995      904  139.502160              POS            Travel
# 9997            3485      527   71.012122           Online            Travel
# 9998            7922      771   21.031405               QR           Grocery
# 9999            6451      429   54.028632              ATM       Electronics
#
# ...

# %%
df['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    9500
# 1     500
# Name: count, dtype: int64

# %%
(df['is_fraud'] == 1).mean() * 100
# Out:
# np.float64(5.0)

# %%
(df['is_fraud'] == 0).mean() * 100
# Out:
# np.float64(95.0)

# %%
df.loc[len(df)] = [10001,9999,123.23,'ATM','Travel','US',20,0.2,0.9,1]

# %%
df.tail()
# Out:
#        transaction_id  user_id      amount transaction_type merchant_category  \
# 9996             4995      904  139.502160              POS            Travel
# 9997             3485      527   71.012122           Online            Travel
# 9998             7922      771   21.031405               QR           Grocery
# 9999             6451      429   54.028632              ATM       Electronics
# 10000           10001     9999  123.230000              ATM            Travel
#
#       country  hour  device_risk_score  ip_risk_score  is_fraud
# 9996       DE    13           0.119014       0.285680         0
# 9997       TR     8           0.119204       0.262262         0
# 9998       UK    12           0.027088       0.295243         0
# 9999       DE    11           0.096438       0.042823         0
# 10000      US    20           0.200000       0.900000         1

# %%
df = df[df['hour'] >= 10]

# %%
df[df['hour'] < 10]
# Out:
# Empty DataFrame
# Columns: [transaction_id, user_id, amount, transaction_type, merchant_category, country, hour, device_risk_score, ip_risk_score, is_fraud]
# Index: []

# %%
df.isnull().sum()
# Out:
# transaction_id       0
# user_id              0
# amount               0
# transaction_type     0
# merchant_category    0
# country              0
# hour                 0
# device_risk_score    0
# ip_risk_score        0
# is_fraud             0
# dtype: int64

# %%
df = df.sort_values(by='transaction_id')

# %%
df
# Out:
#        transaction_id  user_id       amount transaction_type  \
# 8110                0       21    60.949553              ATM
# 5227                1      348   112.994162              ATM
# 2855                3      682   112.997900           Online
# 7674                6      905   177.909182              ATM
# 4049                8      319    92.918951           Online
# ...               ...      ...          ...              ...
# 8719             9993      328  1637.680200               QR
# 9624             9995      478  2661.977484               QR
# 9667             9997      574  6427.530530           Online
# 9441             9998      411  3019.952898              POS
# 10000           10001     9999   123.230000              ATM
#
#       merchant_category country  hour  device_risk_score  ip_risk_score  \
# 8110             Travel      US    17           0.154740       0.277348
# 5227             Travel      FR    23           0.163606       0.199545
# ...

# %%
df.to_csv('update.csv',index = False)
